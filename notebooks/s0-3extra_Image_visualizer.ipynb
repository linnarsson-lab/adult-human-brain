# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.display import Image
Image("/data2/loom_files/development/autogenerated_figures/complexity_flags/10X39_2.png")

# %%
Image("/data2/loom_files/development/autogenerated_figures/complexity_flags/10X08_1.png")

# %%
Image("/data2/loom_files/development/autogenerated_figures/complexity_flags/10X23_4.png")

# %%
Image("/data2/loom_files/development/autogenerated_figures/complexity_flags/10X29_3.png")

# %%
Image("/data2/loom_files/development/autogenerated_figures/complexity_flags/10X30_4.png")
